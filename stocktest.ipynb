# %%
print("OK")
# Out:
# OK

# %%
pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip show yfinance
# Out:
# Name: yfinance
# Version: 1.1.0
# Summary: Download market data from Yahoo! Finance API
# Home-page: https://github.com/ranaroussi/yfinance
# Author: Ran Aroussi
# Author-email: ran@aroussi.com
# License: Apache
# Location: C:\Users\Administrator\AppData\Local\Programs\Python\Python313\Lib\site-packages
# Requires: beautifulsoup4, curl_cffi, frozendict, multitasking, numpy, pandas, peewee, platformdirs, protobuf, pytz, requests, websockets
# Required-by:

# %%
import yfinance as yf

stock = yf.Ticker("AAPL")

price=stock.info["currentPrice"]
print("Current Price of Apple Stock:", price)
# Out:
# Current Price of Apple Stock: 270.01

# %%
btc=yf.download("BTC-USD", period="7d", interval="1h")
print(btc)

eth=yf.download("ETH-USD")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Price                             Close          High           Low  \
# Ticker                          BTC-USD       BTC-USD       BTC-USD
# Datetime
# 2026-01-28 00:00:00+00:00  89275.367188  89322.437500  89039.734375
# 2026-01-28 01:00:00+00:00  89307.570312  89367.554688  89093.585938
# 2026-01-28 02:00:00+00:00  89121.609375  89309.617188  88993.328125
# 2026-01-28 03:00:00+00:00  89013.218750  89157.382812  88884.531250
# 2026-01-28 04:00:00+00:00  88890.562500  89035.757812  88741.304688
# ...                                 ...           ...           ...
# 2026-02-03 02:00:00+00:00  77810.250000  78950.703125  77810.250000
# 2026-02-03 03:00:00+00:00  78719.218750  78804.734375  77604.507812
# 2026-02-03 04:00:00+00:00  78717.812500  78908.914062  78440.468750
# 2026-02-03 05:00:00+00:00  78190.984375  78735.695312  78190.984375
# ...

# %%
eth=yf.download("ETH-USD")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
print(stock.info["marketCap"])
print(stock.splits)
# Out:
# 3968587005952
# Date
# 1987-06-16 00:00:00-04:00    2.0
# 2000-06-21 00:00:00-04:00    2.0
# 2005-02-28 00:00:00-05:00    2.0
# 2014-06-09 00:00:00-04:00    7.0
# 2020-08-31 00:00:00-04:00    4.0
# Name: Stock Splits, dtype: float64

# %%
stocks=["AAPL","MSFT","GOOGL"]
df=yf.download(stocks, period="5d", interval="1d")
print(df)
# Out:
# [*********************100%***********************]  3 of 3 completed
# Price            Close                                High              \
# Ticker            AAPL       GOOGL        MSFT        AAPL       GOOGL
# Date
# 2026-01-27  258.269989  334.549988  480.579987  261.950012  337.910004
# 2026-01-28  256.440002  336.010010  481.630005  258.859985  337.540009
# 2026-01-29  258.279999  338.250000  433.500000  259.649994  342.290009
# 2026-01-30  259.480011  338.000000  430.290009  261.899994  340.000000
# 2026-02-02  270.010010  343.690002  423.369995  270.489990  344.829987
#
# Price                          Low                                Open  \
# Ticker            MSFT        AAPL       GOOGL        MSFT        AAPL
# Date
# 2026-01-27  482.869995  258.209991  333.480011  473.160004  259.170013
# 2026-01-28  483.739990  254.509995  331.940002  478.000000  257.649994
# 2026-01-29  442.500000  254.410004  326.540009  421.019989  258.000000
# ...
